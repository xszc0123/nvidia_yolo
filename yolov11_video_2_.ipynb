# %% [markdown]
# <a href="https://colab.research.google.com/github/xszc0123/nvidia_yolo/blob/20250404/yolov11_video_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. YOLOv8 설치 및 라이브러리 불러오기
# !pip install ultralytics opencv-python
import cv2
import torch
from ultralytics import YOLO
from google.colab.patches import cv2_imshow
from IPython.display import display, HTML
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 977.3/977.3 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 36.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# 2. YOLOv8 모델 로드 (사전 학습된 모델 사용)
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 65.4MB/s]

# %%
# 3. 동영상 파일 업로드
from google.colab import files
uploaded = files.upload()
video_path = list(uploaded.keys())[0]  # 업로드된 파일 경로
# Out:
#      <input type="file" id="files-98b94824-c73b-4378-a88d-554a34ae2db9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98b94824-c73b-4378-a88d-554a34ae2db9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 4. 동영상 읽기 및 객체 탐지
cap = cv2.VideoCapture(video_path)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
output_path = "output.mp4"

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    annotated_frame = results[0].plot()
    out.write(annotated_frame)

cap.release()
out.release()
# Out:
# 0: 352x640 13 persons, 326.6ms
# Speed: 18.6ms preprocess, 326.6ms inference, 35.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 persons, 136.4ms
# Speed: 4.7ms preprocess, 136.4ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 persons, 136.7ms
# Speed: 3.4ms preprocess, 136.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 13 persons, 1 tennis racket, 145.7ms
# Speed: 3.5ms preprocess, 145.7ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 persons, 1 traffic light, 2 backpacks, 134.7ms
# Speed: 7.0ms preprocess, 134.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 persons, 1 traffic light, 1 backpack, 137.0ms
# Speed: 5.0ms preprocess, 137.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 12 persons, 1 traffic light, 2 backpacks, 135.0ms
# ...

# %%
# 5. 분석된 동영상 다운로드
from google.colab import files
files.download(output_path)
