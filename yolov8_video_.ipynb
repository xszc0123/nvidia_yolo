# %% [markdown]
# <a href="https://colab.research.google.com/github/xszc0123/nvidia_yolo/blob/20250404/yolov8_video_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from google.colab import files

# 파일 업로드 창 열기
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7fef577d-ec06-4def-bf5f-d5c810ca0e1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fef577d-ec06-4def-bf5f-d5c810ca0e1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO
import cv2

# YOLOv8 모델 로드
model = YOLO("yolov8n.pt")

# 동영상 경로 (업로드한 파일)
video_path = "/content/car.mp4"

# 동영상 불러오기
cap = cv2.VideoCapture(video_path)

# 결과 저장을 위한 설정
output_path = "/content/output.mp4"
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # YOLOv8 객체 감지
    results = model(frame)

    # 감지 결과를 프레임에 적용
    annotated_frame = results[0].plot()

    # 저장
    out.write(annotated_frame)

cap.release()
out.release()
# Out:
# 0: 352x640 10 cars, 1 bus, 224.5ms
# Speed: 4.9ms preprocess, 224.5ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 10 cars, 1 bus, 212.1ms
# Speed: 4.0ms preprocess, 212.1ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 bus, 219.4ms
# Speed: 5.1ms preprocess, 219.4ms inference, 1.8ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 bus, 243.8ms
# Speed: 4.7ms preprocess, 243.8ms inference, 2.7ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 8 cars, 1 bus, 150.7ms
# Speed: 5.1ms preprocess, 150.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 9 cars, 1 bus, 147.2ms
# Speed: 4.8ms preprocess, 147.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 352x640 11 cars, 1 bus, 142.4ms
# Speed: 4.8ms preprocess, 142.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# ...

# %%
from google.colab import files
files.download("/content/output.mp4")
